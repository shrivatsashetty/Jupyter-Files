# %%
import os
import pathlib

# %%
print("EDA Demo")
# Out:
# EDA Demo

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/shrivatsa/Downloads/Customer-Churn.csv')

# %%
df
# Out:
#       Call  Failure  Complains  Subscription  Length  Charge  Amount  \
# 0                 8          0                    38               0
# 1                 0          0                    39               0
# 2                10          0                    37               0
# 3                10          0                    38               0
# 4                 3          0                    38               0
# ...             ...        ...                   ...             ...
# 3145             21          0                    19               2
# 3146             17          0                    17               1
# 3147             13          0                    18               4
# 3148              7          0                    11               2
# 3149              8          1                    11               2
#
#       Seconds of Use  Frequency of use  Frequency of SMS  \
# 0               4370                71                 5
# ...

# %%
pd.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pd.describe()
#
# AttributeError: module 'pandas' has no attribute 'describe'
